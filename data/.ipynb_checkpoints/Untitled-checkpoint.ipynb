# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import os

# Ensure data folder exists
os.makedirs("data", exist_ok=True)

# Fake names
agents = ["John", "Sarah", "Ali", "Mona"]
leaders = ["Amira", "Hassan"]
supervisors = ["Omar", "Nour"]

# Generate 30 days
days = [datetime.today() - timedelta(days=i) for i in range(30)]

rows = []
for day in days:
    for agent in agents:
        row = {
            "day": day.strftime("%Y-%m-%d"),
            "agent": agent,
            "team_leader": np.random.choice(leaders),
            "supervisor": np.random.choice(supervisors),
            "total_chats": np.random.randint(10, 50),
            "avg_response_time": np.random.uniform(30, 300),
            "csat": np.random.uniform(0.7, 1.0),
            "active_agents": np.random.randint(1, 10),
            "escalations": np.random.randint(0, 5),
            "resolved": np.random.uniform(0.5, 1.0),
            "pending": np.random.randint(0, 10),
            "avg_chat_duration": np.random.uniform(3, 15),
            "sales_conversion": np.random.uniform(0, 0.5),
            "avg_queue_time": np.random.uniform(5, 120)
        }
        rows.append(row)

df = pd.DataFrame(rows)
df.to_csv("data.csv", index=False)
print("Fake data generated at data/data.csv")
# Out:
# Fake data generated at data/data.csv
